# %%
# import libaries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# api keys

# omdb (open movie database). get a free api key here: https://www.omdbapi.com/
apikey_omdb = 'c733b530'

# %%
# json file of all star trek scripts can be found here: https://www.kaggle.com/gjbroughton/start-trek-scripts 

# read in the json file
df = pd.read_json('all_series_lines.json')

df.head()
# Out:
#                                                          ENT  \
# episode 0  {'KLAANG': ['', '', 'Pung ghap! Pung ghap!', '...
# episode 1  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['Come in...
# episode 2  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['T'Pol.'...
# episode 3  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['Archer ...
# episode 4  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['Are we ...
#
#                                                          DS9  \
# episode 0  {'JENNIFER': ['Hey!', 'Yes?', 'I'm sorry did w...
# episode 1  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
# episode 2  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
# episode 3  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
# episode 4  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
#
#                                                          TOS  \
# episode 0  {'HASKINS': ['Doctor Theodore Haskins, America...
# episode 1  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
# episode 2  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
# episode 3  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
# episode 4  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
#
#                                                          TAS  \
# episode 0  {'MCCOY': ['If its pull is this strong, Jim, h...
# episode 1  {'MCCOY': ['Who's he, Jim?', 'Afraid I don't, ...
# episode 2  {'MCCOY': ['Jim, if we can't stop it, millions...
# episode 3  {'MCCOY': ['Magnolias in blossom. Beautiful.',...
# episode 4  {'MCCOY': ['I don't want to think about it.', ...
#
#                                                          TNG  \
# episode 0  {'BAILIFF': ['The prisoners will all stand.', ...
# episode 1  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['Repor...
# episode 2  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['On ou...
# episode 3  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['Enlar...
# episode 4  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['I don...
#
#                                                          VOY
# episode 0  {'JANEWAY': ['Tom Paris? Kathryn Janeway. I se...
# episode 1  {'JANEWAY': ['What about alternative energy so...
# episode 2  {'JANEWAY': ['Report!', 'Mister Paris, can you...
# episode 3  {'JANEWAY': ['Assuming we do find dilithium on...
# episode 4  {'JANEWAY': ['Personal log,Stardate 48546.2. O...

# %%
# create list of episodes in ds9 series

ds9_episodes = df['DS9'].keys()

ds9_episodes
# Out:
# Index(['episode 0', 'episode 1', 'episode 2', 'episode 3', 'episode 4',
#        'episode 5', 'episode 6', 'episode 7', 'episode 8', 'episode 9',
#        ...
#        'episode 166', 'episode 167', 'episode 168', 'episode 169',
#        'episode 170', 'episode 171', 'episode 172', 'episode 173',
#        'episode 174', 'episode 175'],
#       dtype='object', length=176)

# %%
# count number of lines per character per episode and put in dataframe

episodes = []
characters = []
lines = []

for ep in np.arange(len(ds9_episodes)):

    if df['DS9'][ds9_episodes[ep]] is not np.NaN:
    
        for character in list(df['DS9'][ds9_episodes[ep]].keys()):
        
            line_count = len(df['DS9'][ds9_episodes[ep]][character])    
            
            episodes.append(ep)
            characters.append(character)
            lines.append(line_count)
            
df_ds9 = pd.DataFrame({'episode': episodes,
                       'character': characters,
                       'line_count': lines
                      })

df_ds9.head()
# Out:
#    episode character  line_count
# 0        0  JENNIFER          41
# 1        0       OPS           4
# 2        0     JASAD          13
# 3        0    PICARD          28
# 4        0    MAGGIE           1

# %%
# do a little cleanup

# replace instances of 'DAX' with 'JADZIA'
df_ds9['character'] = df_ds9['character'].replace(['EZRI'],'DAX')

# clean up O'BRIEN names 
df_ds9['character'] = df_ds9['character'].replace(["youO'BRIEN", "wasO'BRIEN", "0'BRIEN"],"O'BRIEN")


# remove instances where line_count equals zero
df_ds9 = df_ds9[df_ds9['line_count'] != 0]

# add 1 to episode and change to string

df_ds9['seriesEpisode'] = df_ds9['episode'] + 1

# %%
# list out characters with most lines

top_characters = df_ds9.groupby('character')['line_count'].sum().sort_values(ascending=False).head(25)

top_characters
# Out:
# character
# SISKO        8664
# KIRA         5495
# BASHIR       5151
# O'BRIEN      4980
# DAX          4896
# ODO          4779
# QUARK        4501
# WORF         2085
# JAKE         1612
# GARAK        1492
# NOG          1304
# DUKAT        1279
# ROM          1209
# WEYOUN        555
# WINN          520
# KEIKO         494
# MARTOK        482
# DAMAR         433
# KASIDY        372
# VIC           357
# ZEK           355
# COMPUTER      341
# BAREIL        311
# EDDINGTON     300
# FOUNDER       255
# Name: line_count, dtype: int64

# %%
top_characters_clean = top_characters[~top_characters.index.isin(['COMPUTER', 'ZEK', 'VIC', 'BAREIL', 'KASIDY', 'EDDINGTON', 'KEIKO', 'FOUNDER'])]

fig, ax = plt.subplots(figsize=(10,5))
top_characters_clean.plot.bar();

# %%
url = 'http://www.omdbapi.com/'
title = 'deep+space+nine'

for season in np.arange(1,8):

    params = {'apikey': apikey_omdb,
              't': title,
              'season': season}

    response = requests.get(url, params)

    data = response.json()
    
    df_season = pd.DataFrame(data)
    
    if season == 1:
    
        df_omdb = df_season
    
    else:
        
        df_omdb = df_omdb.append(df_season)

df_omdb.reset_index(drop=True, inplace=True)


# split Episodes column in separate columns and put in dataframe

df_episodes = df_omdb['Episodes'].apply(pd.Series)

df_episodes


# rename show 'Title' as 'Series'
df_omdb = df_omdb.rename(columns={'Title': 'Series'})

df_omdb = df_omdb.join(df_episodes)

df_omdb["seriesEpisode"] = df_omdb.index + 1

df_omdb
# Out:
#                          Series Season totalSeasons  \
# 0    Star Trek: Deep Space Nine      1            7
# 1    Star Trek: Deep Space Nine      1            7
# 2    Star Trek: Deep Space Nine      1            7
# 3    Star Trek: Deep Space Nine      1            7
# 4    Star Trek: Deep Space Nine      1            7
# ..                          ...    ...          ...
# 168  Star Trek: Deep Space Nine      7            7
# 169  Star Trek: Deep Space Nine      7            7
# 170  Star Trek: Deep Space Nine      7            7
# 171  Star Trek: Deep Space Nine      7            7
# 172  Star Trek: Deep Space Nine      7            7
#
#                                               Episodes Response  \
# 0    {'Title': 'Emissary', 'Released': '1993-01-03'...     True
# 1    {'Title': 'Past Prologue', 'Released': '1993-0...     True
# 2    {'Title': 'A Man Alone', 'Released': '1993-01-...     True
# 3    {'Title': 'Babel', 'Released': '1993-01-24', '...     True
# 4    {'Title': 'Captive Pursuit', 'Released': '1993...     True
# ..                                                 ...      ...
# 168  {'Title': 'When It Rains...', 'Released': '199...     True
# 169  {'Title': 'Tacking Into The Wind', 'Released':...     True
# 170  {'Title': 'Extreme Measures', 'Released': '199...     True
# 171  {'Title': 'The Dogs Of War', 'Released': '1999...     True
# 172  {'Title': 'What You Leave Behind', 'Released':...     True
#
#                      Title    Released Episode imdbRating     imdbID  \
# 0                 Emissary  1993-01-03       1        7.6  tt0108214
# 1            Past Prologue  1993-01-10       2        7.1  tt0708576
# 2              A Man Alone  1993-01-17       3        6.9  tt0708494
# 3                    Babel  1993-01-24       4        7.0  tt0708501
# 4          Captive Pursuit  1993-01-31       5        7.7  tt0708513
# ..                     ...         ...     ...        ...        ...
# 168       When It Rains...  1999-05-05      21        8.3  tt0708663
# 169  Tacking Into The Wind  1999-05-12      22        8.8  tt0708608
# 170       Extreme Measures  1999-05-19      23        7.8  tt0708535
# 171        The Dogs Of War  1999-05-26      24        8.4  tt0708622
# 172  What You Leave Behind  1999-06-02      25        9.0  tt0394907
#
#      seriesEpisode
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
# ..             ...
# 168            169
# 169            170
# 170            171
# 171            172
# 172            173
#
# [173 rows x 11 columns]

# %%
df_merge = df_ds9.merge(df_omdb, on='seriesEpisode', how='inner')

df_merge.head()
# Out:
#    episode character  line_count  seriesEpisode                      Series  \
# 0        0  JENNIFER          41              1  Star Trek: Deep Space Nine
# 1        0       OPS           4              1  Star Trek: Deep Space Nine
# 2        0     JASAD          13              1  Star Trek: Deep Space Nine
# 3        0    PICARD          28              1  Star Trek: Deep Space Nine
# 4        0    MAGGIE           1              1  Star Trek: Deep Space Nine
#
#   Season totalSeasons                                           Episodes  \
# 0      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 1      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 2      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 3      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 4      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
#
#   Response     Title    Released Episode imdbRating     imdbID
# 0     True  Emissary  1993-01-03       1        7.6  tt0108214
# 1     True  Emissary  1993-01-03       1        7.6  tt0108214
# 2     True  Emissary  1993-01-03       1        7.6  tt0108214
# 3     True  Emissary  1993-01-03       1        7.6  tt0108214
# 4     True  Emissary  1993-01-03       1        7.6  tt0108214

# %%
df_top_characters = df_merge[df_merge['character'].isin(top_characters_clean.index)]

df_top_characters.head()
# Out:
#     episode character  line_count  seriesEpisode                      Series  \
# 5         0     DUKAT           9              1  Star Trek: Deep Space Nine
# 8         0      KIRA          85              1  Star Trek: Deep Space Nine
# 10        0     SISKO         192              1  Star Trek: Deep Space Nine
# 15        0       ODO          21              1  Star Trek: Deep Space Nine
# 16        0   O'BRIEN          69              1  Star Trek: Deep Space Nine
#
#    Season totalSeasons                                           Episodes  \
# 5       1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 8       1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 10      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 15      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 16      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
#
#    Response     Title    Released Episode imdbRating     imdbID
# 5      True  Emissary  1993-01-03       1        7.6  tt0108214
# 8      True  Emissary  1993-01-03       1        7.6  tt0108214
# 10     True  Emissary  1993-01-03       1        7.6  tt0108214
# 15     True  Emissary  1993-01-03       1        7.6  tt0108214
# 16     True  Emissary  1993-01-03       1        7.6  tt0108214

# %%
sum_lines_per_episode = df_top_characters.groupby('seriesEpisode')['line_count'].sum()

sum_lines_per_episode
# Out:
# seriesEpisode
# 1      483
# 2      305
# 3      295
# 4      328
# 5      251
#       ...
# 169    327
# 170    241
# 171    360
# 172    282
# 173    620
# Name: line_count, Length: 173, dtype: int64

# %%
df_top_characters = df_top_characters.merge(sum_lines_per_episode, on='seriesEpisode', suffixes=('','_episode_total'))

df_top_characters
# Out:
#       episode character  line_count  seriesEpisode  \
# 0           0     DUKAT           9              1
# 1           0      KIRA          85              1
# 2           0     SISKO         192              1
# 3           0       ODO          21              1
# 4           0   O'BRIEN          69              1
# ...       ...       ...         ...            ...
# 1568      172      WORF          24            173
# 1569      172    MARTOK          17            173
# 1570      172     DAMAR          22            173
# 1571      172    WEYOUN          43            173
# 1572      172       DAX          39            173
#
#                           Series Season totalSeasons  \
# 0     Star Trek: Deep Space Nine      1            7
# 1     Star Trek: Deep Space Nine      1            7
# 2     Star Trek: Deep Space Nine      1            7
# 3     Star Trek: Deep Space Nine      1            7
# 4     Star Trek: Deep Space Nine      1            7
# ...                          ...    ...          ...
# 1568  Star Trek: Deep Space Nine      7            7
# 1569  Star Trek: Deep Space Nine      7            7
# 1570  Star Trek: Deep Space Nine      7            7
# 1571  Star Trek: Deep Space Nine      7            7
# 1572  Star Trek: Deep Space Nine      7            7
#
#                                                Episodes Response  \
# 0     {'Title': 'Emissary', 'Released': '1993-01-03'...     True
# 1     {'Title': 'Emissary', 'Released': '1993-01-03'...     True
# 2     {'Title': 'Emissary', 'Released': '1993-01-03'...     True
# 3     {'Title': 'Emissary', 'Released': '1993-01-03'...     True
# 4     {'Title': 'Emissary', 'Released': '1993-01-03'...     True
# ...                                                 ...      ...
# 1568  {'Title': 'What You Leave Behind', 'Released':...     True
# 1569  {'Title': 'What You Leave Behind', 'Released':...     True
# 1570  {'Title': 'What You Leave Behind', 'Released':...     True
# 1571  {'Title': 'What You Leave Behind', 'Released':...     True
# 1572  {'Title': 'What You Leave Behind', 'Released':...     True
#
#                       Title    Released Episode imdbRating     imdbID  \
# 0                  Emissary  1993-01-03       1        7.6  tt0108214
# 1                  Emissary  1993-01-03       1        7.6  tt0108214
# 2                  Emissary  1993-01-03       1        7.6  tt0108214
# 3                  Emissary  1993-01-03       1        7.6  tt0108214
# 4                  Emissary  1993-01-03       1        7.6  tt0108214
# ...                     ...         ...     ...        ...        ...
# 1568  What You Leave Behind  1999-06-02      25        9.0  tt0394907
# 1569  What You Leave Behind  1999-06-02      25        9.0  tt0394907
# 1570  What You Leave Behind  1999-06-02      25        9.0  tt0394907
# 1571  What You Leave Behind  1999-06-02      25        9.0  tt0394907
# 1572  What You Leave Behind  1999-06-02      25        9.0  tt0394907
#
#       line_count_episode_total
# 0                          483
# 1                          483
# 2                          483
# 3                          483
# 4                          483
# ...                        ...
# 1568                       620
# 1569                       620
# 1570                       620
# 1571                       620
# 1572                       620
#
# [1573 rows x 15 columns]

# %%
df_top_characters['episodeFraction'] = df_top_characters['line_count'] / df_top_characters['line_count_episode_total']

df_top_characters['ratingFraction'] = df_top_characters['episodeFraction'] * df_top_characters['imdbRating'].astype(float)

df_top_characters.head()
# Out:
#    episode character  line_count  seriesEpisode                      Series  \
# 0        0     DUKAT           9              1  Star Trek: Deep Space Nine
# 1        0      KIRA          85              1  Star Trek: Deep Space Nine
# 2        0     SISKO         192              1  Star Trek: Deep Space Nine
# 3        0       ODO          21              1  Star Trek: Deep Space Nine
# 4        0   O'BRIEN          69              1  Star Trek: Deep Space Nine
#
#   Season totalSeasons                                           Episodes  \
# 0      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 1      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 2      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 3      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
# 4      1            7  {'Title': 'Emissary', 'Released': '1993-01-03'...
#
#   Response     Title    Released Episode imdbRating     imdbID  \
# 0     True  Emissary  1993-01-03       1        7.6  tt0108214
# 1     True  Emissary  1993-01-03       1        7.6  tt0108214
# 2     True  Emissary  1993-01-03       1        7.6  tt0108214
# 3     True  Emissary  1993-01-03       1        7.6  tt0108214
# 4     True  Emissary  1993-01-03       1        7.6  tt0108214
#
#    line_count_episode_total  episodeFraction  ratingFraction
# 0                       483         0.018634        0.141615
# 1                       483         0.175983        1.337474
# 2                       483         0.397516        3.021118
# 3                       483         0.043478        0.330435
# 4                       483         0.142857        1.085714

# %%
df_top_characters.to_csv('ds9_character_analysis.csv')

# %%
ratingPoints = df_top_characters.groupby('character')['ratingFraction'].sum()

ratingPoints
# Out:
# character
# BASHIR     143.403871
# DAMAR       10.943109
# DAX        129.200341
# DUKAT       33.975719
# GARAK       40.582221
# JAKE        42.846526
# KIRA       147.802884
# MARTOK      13.927510
# NOG         35.024392
# O'BRIEN    135.155644
# ODO        125.106069
# QUARK      113.375479
# ROM         29.687554
# SISKO      233.625848
# WEYOUN      13.633349
# WINN        13.417913
# WORF        54.691572
# Name: ratingFraction, dtype: float64

# %%
episodes_count = df_top_characters.groupby('character')['seriesEpisode'].count()

episodes_count
# Out:
# character
# BASHIR     169
# DAMAR       23
# DAX        171
# DUKAT       34
# GARAK       38
# JAKE        71
# KIRA       171
# MARTOK      24
# NOG         46
# O'BRIEN    163
# ODO        167
# QUARK      154
# ROM         35
# SISKO      173
# WEYOUN      23
# WINN        14
# WORF        97
# Name: seriesEpisode, dtype: int64

# %%
df_final = pd.concat([ratingPoints, episodes_count], axis=1)
df_final['score'] = df_final['ratingFraction'] / df_final['seriesEpisode']
df_final = df_final.sort_values(by='score', ascending=False)

df_final
# Out:
#            ratingFraction  seriesEpisode     score
# character
# SISKO          233.625848            173  1.350438
# GARAK           40.582221             38  1.067953
# DUKAT           33.975719             34  0.999286
# WINN            13.417913             14  0.958422
# KIRA           147.802884            171  0.864344
# BASHIR         143.403871            169  0.848544
# ROM             29.687554             35  0.848216
# O'BRIEN        135.155644            163  0.829176
# NOG             35.024392             46  0.761400
# DAX            129.200341            171  0.755558
# ODO            125.106069            167  0.749138
# QUARK          113.375479            154  0.736204
# JAKE            42.846526             71  0.603472
# WEYOUN          13.633349             23  0.592754
# MARTOK          13.927510             24  0.580313
# WORF            54.691572             97  0.563831
# DAMAR           10.943109             23  0.475787

# %%
fig, ax = plt.subplots()

df_final['score'].plot.bar();
