# %%
# import libaries

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# api keys

# omdb (open movie database). get a free api key here: https://www.omdbapi.com/
apikey_omdb = 'c733b530'

# %%
# json file of all star trek scripts can be found here: https://www.kaggle.com/gjbroughton/start-trek-scripts 

# read in the json file
df = pd.read_json('all_series_lines.json')

df.head()
# Out:
#                                                          ENT  \
# episode 0  {'KLAANG': ['', '', 'Pung ghap! Pung ghap!', '...
# episode 1  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['Come in...
# episode 2  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['T'Pol.'...
# episode 3  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['Archer ...
# episode 4  {'KLAANG': [], 'DOCK': [], 'ARCHER': ['Are we ...
#
#                                                          DS9  \
# episode 0  {'JENNIFER': ['Hey!', 'Yes?', 'I'm sorry did w...
# episode 1  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
# episode 2  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
# episode 3  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
# episode 4  {'JENNIFER': [], 'OPS': [], 'JASAD': [], 'PICA...
#
#                                                          TOS  \
# episode 0  {'HASKINS': ['Doctor Theodore Haskins, America...
# episode 1  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
# episode 2  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
# episode 3  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
# episode 4  {'HASKINS': [], 'TALOSIAN': [], 'GEOLOGIST': [...
#
#                                                          TAS  \
# episode 0  {'MCCOY': ['If its pull is this strong, Jim, h...
# episode 1  {'MCCOY': ['Who's he, Jim?', 'Afraid I don't, ...
# episode 2  {'MCCOY': ['Jim, if we can't stop it, millions...
# episode 3  {'MCCOY': ['Magnolias in blossom. Beautiful.',...
# episode 4  {'MCCOY': ['I don't want to think about it.', ...
#
#                                                          TNG  \
# episode 0  {'BAILIFF': ['The prisoners will all stand.', ...
# episode 1  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['Repor...
# episode 2  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['On ou...
# episode 3  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['Enlar...
# episode 4  {'BAILIFF': [], 'MCCOY': [], 'PICARD': ['I don...
#
#                                                          VOY
# episode 0  {'JANEWAY': ['Tom Paris? Kathryn Janeway. I se...
# episode 1  {'JANEWAY': ['What about alternative energy so...
# episode 2  {'JANEWAY': ['Report!', 'Mister Paris, can you...
# episode 3  {'JANEWAY': ['Assuming we do find dilithium on...
# episode 4  {'JANEWAY': ['Personal log,Stardate 48546.2. O...

# %%
# create list of episodes in ds9 series

ds9_episodes = df['DS9'].keys()

ds9_episodes
# Out:
# Index(['episode 0', 'episode 1', 'episode 2', 'episode 3', 'episode 4',
#        'episode 5', 'episode 6', 'episode 7', 'episode 8', 'episode 9',
#        ...
#        'episode 166', 'episode 167', 'episode 168', 'episode 169',
#        'episode 170', 'episode 171', 'episode 172', 'episode 173',
#        'episode 174', 'episode 175'],
#       dtype='object', length=176)

# %%
# count number of lines per character per episode and put in dataframe

episodes = []
characters = []
lines = []

for ep in np.arange(len(ds9_episodes)):

    if df['DS9'][ds9_episodes[ep]] is not np.NaN:
    
        for character in list(df['DS9'][ds9_episodes[ep]].keys()):
        
            line_count = len(df['DS9'][ds9_episodes[ep]][character])    
            
            episodes.append(ep)
            characters.append(character)
            lines.append(line_count)
            
df_ds9 = pd.DataFrame({'episode': episodes,
                       'character': characters,
                       'line_count': lines
                      })

df_ds9.head()
# Out:
#    episode character  line_count
# 0        0  JENNIFER          41
# 1        0       OPS           4
# 2        0     JASAD          13
# 3        0    PICARD          28
# 4        0    MAGGIE           1

# %%
# do a little cleanup

# replace instances of 'DAX' with 'JADZIA'
df_ds9['character'] = df_ds9['character'].replace(['EZRI'],'DAX')

# clean up O'BRIEN names 
df_ds9['character'] = df_ds9['character'].replace(["youO'BRIEN", "wasO'BRIEN", "0'BRIEN"],"O'BRIEN")


# remove instances where line_count equals zero
df_ds9 = df_ds9[df_ds9['line_count'] != 0]

# add 1 to episode and change to string

df_ds9['seriesEpisode'] = df_ds9['episode'] + 1

# %%
# list out characters with most lines

top_characters = df_ds9.groupby('character')['line_count'].sum().sort_values(ascending=False).head(25)

top_characters
# Out:
# character
# SISKO        8664
# KIRA         5495
# BASHIR       5151
# O'BRIEN      4980
# DAX          4896
# ODO          4779
# QUARK        4501
# WORF         2085
# JAKE         1612
# GARAK        1492
# NOG          1304
# DUKAT        1279
# ROM          1209
# WEYOUN        555
# WINN          520
# KEIKO         494
# MARTOK        482
# DAMAR         433
# KASIDY        372
# VIC           357
# ZEK           355
# COMPUTER      341
# BAREIL        311
# EDDINGTON     300
# FOUNDER       255
# Name: line_count, dtype: int64

# %%
#top_characters_clean = top_characters[~top_characters.index.isin(['COMPUTER', 'ZEK', 'VIC', 'BAREIL', 'KASIDY', 'EDDINGTON', 'KEIKO', 'FOUNDER'])]
top_characters_clean = top_characters[~top_characters.index.isin(['COMPUTER'])]

fig, ax = plt.subplots(figsize=(10,5))
top_characters_clean.plot.bar();

# %%
url = 'http://www.omdbapi.com/'
title = 'deep+space+nine'

for season in np.arange(1,8):

    params = {'apikey': apikey_omdb,
              't': title,
              'season': season}

    response = requests.get(url, params)

    data = response.json()
    
    df_season = pd.DataFrame(data)
    
    if season == 1:
    
        df_omdb = df_season
    
    else:
        
        df_omdb = df_omdb.append(df_season)

df_omdb.reset_index(drop=True, inplace=True)


# split Episodes column in separate columns and put in dataframe

df_episodes = df_omdb['Episodes'].apply(pd.Series)

df_episodes


# rename show 'Title' as 'Series'
df_omdb = df_omdb.rename(columns={'Title': 'Series'})

df_omdb = df_omdb.join(df_episodes)

df_omdb["seriesEpisode"] = df_omdb.index + 1
# Out:
#                          Series Season totalSeasons  \
# 0    Star Trek: Deep Space Nine      1            7
# 1    Star Trek: Deep Space Nine      1            7
# 2    Star Trek: Deep Space Nine      1            7
# 3    Star Trek: Deep Space Nine      1            7
# 4    Star Trek: Deep Space Nine      1            7
# ..                          ...    ...          ...
# 168  Star Trek: Deep Space Nine      7            7
# 169  Star Trek: Deep Space Nine      7            7
# 170  Star Trek: Deep Space Nine      7            7
# 171  Star Trek: Deep Space Nine      7            7
# 172  Star Trek: Deep Space Nine      7            7
#
#                                               Episodes Response  \
# 0    {'Title': 'Emissary', 'Released': '1993-01-03'...     True
# 1    {'Title': 'Past Prologue', 'Released': '1993-0...     True
# 2    {'Title': 'A Man Alone', 'Released': '1993-01-...     True
# 3    {'Title': 'Babel', 'Released': '1993-01-24', '...     True
# 4    {'Title': 'Captive Pursuit', 'Released': '1993...     True
# ..                                                 ...      ...
# 168  {'Title': 'When It Rains...', 'Released': '199...     True
# 169  {'Title': 'Tacking Into The Wind', 'Released':...     True
# 170  {'Title': 'Extreme Measures', 'Released': '199...     True
# 171  {'Title': 'The Dogs Of War', 'Released': '1999...     True
# 172  {'Title': 'What You Leave Behind', 'Released':...     True
#
#                      Title    Released Episode imdbRating     imdbID  \
# 0                 Emissary  1993-01-03       1        7.6  tt0108214
# 1            Past Prologue  1993-01-10       2        7.1  tt0708576
# 2              A Man Alone  1993-01-17       3        6.9  tt0708494
# 3                    Babel  1993-01-24       4        7.0  tt0708501
# 4          Captive Pursuit  1993-01-31       5        7.7  tt0708513
# ..                     ...         ...     ...        ...        ...
# 168       When It Rains...  1999-05-05      21        8.3  tt0708663
# 169  Tacking Into The Wind  1999-05-12      22        8.8  tt0708608
# 170       Extreme Measures  1999-05-19      23        7.8  tt0708535
# 171        The Dogs Of War  1999-05-26      24        8.4  tt0708622
# 172  What You Leave Behind  1999-06-02      25        9.0  tt0394907
#
#      seriesEpisode
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
# ..             ...
# 168            169
# 169            170
# 170            171
# 171            172
# 172            173
#
# [173 rows x 11 columns]

# %%
df_jammer = pd.read_csv('StarTrek_DS9_JammerReviews.csv')

df_jammer.head()
# Out:
#    seriesEpisode  season  seasonEpisode    airDate            title  \
# 0              1       1              1   1/4/1993         Emissary
# 1              2       1              2  1/11/1993    Past Prologue
# 2              3       1              3  1/18/1993      A Man Alone
# 3              4       1              4  1/25/1993            Babel
# 4              5       1              5   2/1/1993  Captive Pursuit
#
#    jammerStars                                        description
# 0          3.5  On the eve of the discovery of the wormhole an...
# 1          3.0  Kira finds her loyalties divided when a Bajora...
# 2          2.0  When the return of a man Odo sent to prison ye...
# 3          2.5  A deadly virus created by the Bajorans 18 year...
# 4          3.0  When O'Brien befriends the station's first vis...

# %%
df_merge = df_ds9.merge(df_jammer, on='seriesEpisode', how='inner')

df_merge.head()
# Out:
#    episode character  line_count  seriesEpisode  season  seasonEpisode  \
# 0        0  JENNIFER          41              1       1              1
# 1        0       OPS           4              1       1              1
# 2        0     JASAD          13              1       1              1
# 3        0    PICARD          28              1       1              1
# 4        0    MAGGIE           1              1       1              1
#
#     airDate     title  jammerStars  \
# 0  1/4/1993  Emissary          3.5
# 1  1/4/1993  Emissary          3.5
# 2  1/4/1993  Emissary          3.5
# 3  1/4/1993  Emissary          3.5
# 4  1/4/1993  Emissary          3.5
#
#                                          description
# 0  On the eve of the discovery of the wormhole an...
# 1  On the eve of the discovery of the wormhole an...
# 2  On the eve of the discovery of the wormhole an...
# 3  On the eve of the discovery of the wormhole an...
# 4  On the eve of the discovery of the wormhole an...

# %%
sum_lines_per_episode = df_merge.groupby('seriesEpisode')['line_count'].sum()

sum_lines_per_episode
# Out:
# seriesEpisode
# 1      664
# 2      419
# 3      389
# 4      399
# 5      355
#       ...
# 169    406
# 170    308
# 171    421
# 172    402
# 173    829
# Name: line_count, Length: 173, dtype: int64

# %%
df_merge = df_merge.merge(sum_lines_per_episode, on='seriesEpisode', suffixes=('','_episode_total'))

df_merge
# Out:
#       episode    character  line_count  seriesEpisode  season  seasonEpisode  \
# 0           0     JENNIFER          41              1       1              1
# 1           0          OPS           4              1       1              1
# 2           0        JASAD          13              1       1              1
# 3           0       PICARD          28              1       1              1
# 4           0       MAGGIE           1              1       1              1
# ...       ...          ...         ...            ...     ...            ...
# 2871      172        BREEN           1            173       7             25
# 2872      172          GOR          17            173       7             25
# 2873      172        BROCA          17            173       7             25
# 2874      172        EKOOR           7            173       7             25
# 2875      172  CARDASSIANS           2            173       7             25
#
#         airDate                  title  jammerStars  \
# 0      1/4/1993               Emissary          3.5
# 1      1/4/1993               Emissary          3.5
# 2      1/4/1993               Emissary          3.5
# 3      1/4/1993               Emissary          3.5
# 4      1/4/1993               Emissary          3.5
# ...         ...                    ...          ...
# 2871  5/31/1999  What You Leave Behind          3.5
# 2872  5/31/1999  What You Leave Behind          3.5
# 2873  5/31/1999  What You Leave Behind          3.5
# 2874  5/31/1999  What You Leave Behind          3.5
# 2875  5/31/1999  What You Leave Behind          3.5
#
#                                             description  \
# 0     On the eve of the discovery of the wormhole an...
# 1     On the eve of the discovery of the wormhole an...
# 2     On the eve of the discovery of the wormhole an...
# 3     On the eve of the discovery of the wormhole an...
# 4     On the eve of the discovery of the wormhole an...
# ...                                                 ...
# 2871  As the war careens toward a final showdown on ...
# 2872  As the war careens toward a final showdown on ...
# 2873  As the war careens toward a final showdown on ...
# 2874  As the war careens toward a final showdown on ...
# 2875  As the war careens toward a final showdown on ...
#
#       line_count_episode_total
# 0                          664
# 1                          664
# 2                          664
# 3                          664
# 4                          664
# ...                        ...
# 2871                       829
# 2872                       829
# 2873                       829
# 2874                       829
# 2875                       829
#
# [2876 rows x 11 columns]

# %%
df_merge['episodeFraction'] = df_merge['line_count'] / df_merge['line_count_episode_total']

df_merge['episodeQuality'] = (df_merge['jammerStars'] - 2)

df_merge['ratingFraction'] = df_merge['episodeFraction'] * df_merge['episodeQuality']

df_merge.head()
# Out:
#    episode character  line_count  seriesEpisode  season  seasonEpisode  \
# 0        0  JENNIFER          41              1       1              1
# 1        0       OPS           4              1       1              1
# 2        0     JASAD          13              1       1              1
# 3        0    PICARD          28              1       1              1
# 4        0    MAGGIE           1              1       1              1
#
#     airDate     title  jammerStars  \
# 0  1/4/1993  Emissary          3.5
# 1  1/4/1993  Emissary          3.5
# 2  1/4/1993  Emissary          3.5
# 3  1/4/1993  Emissary          3.5
# 4  1/4/1993  Emissary          3.5
#
#                                          description  \
# 0  On the eve of the discovery of the wormhole an...
# 1  On the eve of the discovery of the wormhole an...
# 2  On the eve of the discovery of the wormhole an...
# 3  On the eve of the discovery of the wormhole an...
# 4  On the eve of the discovery of the wormhole an...
#
#    line_count_episode_total  episodeFraction  episodeQuality  ratingFraction
# 0                       664         0.061747             1.5        0.092620
# 1                       664         0.006024             1.5        0.009036
# 2                       664         0.019578             1.5        0.029367
# 3                       664         0.042169             1.5        0.063253
# 4                       664         0.001506             1.5        0.002259

# %%
df_merge.to_csv('ds9_character_analysis_jammer.csv')

# %%
ratingPoints = df_merge.groupby('character')['ratingFraction'].sum()

ratingPoints
# Out:
# character
# ADL        0.003409
# ADMIRAL    0.023864
# AFR        0.004425
# AGENT      0.000000
# AH-KEL     0.088983
#              ...
# ZLANGCO    0.031414
# ZOLAN      0.044474
# ZYREE      0.000000
# bat-LEH    0.001437
# mat-LEH    0.001437
# Name: ratingFraction, Length: 694, dtype: float64

# %%
episodes_count = df_merge.groupby('character')['seriesEpisode'].count()

episodes_count
# Out:
# character
# ADL        1
# ADMIRAL    1
# AFR        1
# AGENT      1
# AH-KEL     1
#           ..
# ZLANGCO    1
# ZOLAN      1
# ZYREE      1
# bat-LEH    1
# mat-LEH    1
# Name: seriesEpisode, Length: 694, dtype: int64

# %%
df_final = pd.concat([ratingPoints, episodes_count], axis=1)
df_final['score'] = df_final['ratingFraction'] / df_final['seriesEpisode']
df_final = df_final.sort_values(by='score', ascending=False)
df_final = df_final[df_final.index.isin(top_characters_clean.index)]
df_final
# Out:
#            ratingFraction  seriesEpisode     score
# character
# SISKO           24.379196            173  0.140920
# GARAK            4.860728             38  0.127914
# DUKAT            4.105497             34  0.120750
# WINN             1.505077             14  0.107506
# VIC              0.803120              8  0.100390
# EDDINGTON        0.893519              9  0.099280
# KIRA            14.839808            171  0.086783
# WEYOUN           1.880288             23  0.081752
# NOG              3.727723             46  0.081037
# BASHIR          12.965642            169  0.076720
# O'BRIEN         12.332863            163  0.075662
# ODO             12.150582            167  0.072758
# JAKE             4.618904             71  0.065055
# BAREIL           0.506721              8  0.063340
# DAX             10.795025            171  0.063129
# DAMAR            1.400703             23  0.060900
# KASIDY           0.813222             15  0.054215
# MARTOK           1.298203             24  0.054092
# KEIKO            0.968164             19  0.050956
# WORF             4.670140             97  0.048146
# FOUNDER          0.692620             15  0.046175
# QUARK            6.455987            154  0.041922
# ROM              1.265452             35  0.036156
# ZEK             -0.254480              7 -0.036354

# %%
fig, ax = plt.subplots()

df_final['score'].plot.bar();

# %%
#best couples, thruples, and quadruples?

# sisko & dukat
# sisko & winn
# jake & nog
# garak & bashir
# obrien & bashir
# kira & dukat
# kira & odo
# dukat & winn
# quark, rom, and nog
# quark & odo
# worf & dax
# worf & martok
# weyoun & damar
